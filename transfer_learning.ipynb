# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab10.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 10: Transfer Learning/Fine-Tuning

# %% [markdown]
# ## Description

# %% [markdown]
# ### Objective
#
# - Gain experience fine-tuning pre-trained models to domain-specific applications.
#
# ### Deliverable
#
# For this lab you will submit an IPython notebook via Learning Suite. The bulk of the work is in modifying fine-tuning a pre-trained ResNet. Fine-tuning the GPT-2 language model is pretty easy. The provided code works as is; you will just have to swap in your own text dataset.
#
# ### Grading
#
# - 35% Create a dataset class for your own dataset - In slack, Connor said that we can just use the BirdDataset but to use a different dataset for the GPT portion. I used shakespeare plays.
# - 35% Create a network class that wraps a pretrained ResNet
# - 20% Implement unfreezing in the network class
# - 10% Fine-tune GPT-2 on your own dataset - Done, used shakespeare.txt
#
# ### Tips
# - Your life will be better if you download a dataset that already has the data in the expected format for ImageFolder (make sure to read the documentation!). The datasets recommended below are in the correct format.
# - Get the CNN working on the provided dataset (bird species classification) before swapping in your own.
# - For reference on freezing/unfreezing network weights, see [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c)
# - Check PyTorch's documentation to learn the difference between `requires_grad=False` and `requires_grad_(False)`.
# - For training GPT-2, first try the medium-size (355M parameter) model. If your Colab instance doesn't have enough GPU space, you may need to switch to the small-size (124M parameter) model, but the results will be less impressive.

# %%
from torchvision.models import resnet152
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
import torch
from torch import optim, nn
import zipfile
from google.colab import files
import os
import sys
from PIL import Image, ImageOps
from tqdm import tqdm
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1 Fine-tune a ResNet for image classification

# %% [markdown]
# ### 1.1 Find a dataset to fine-tune on, and make a Dataset class (1 hr.)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Inherit from torch.utils.data.Dataset
# - Use a [torchvision.datasets.ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder)
# - Don't spend too long finding another dataset. Some suggestions that you are free to use:
#  - https://www.kaggle.com/jessicali9530/stanford-dogs-dataset
#  - https://www.kaggle.com/puneet6060/intel-image-classification

# %% [markdown]
# #### Help for downloading kaggle datasets
# Downloading Kaggle datasets requires authentication, so you can't just download from a url. Here are some step-by-step instructions of how to get Kaggle datasets in Colab

# %% [markdown]
# 1. Create an API key in Kaggle
#     - Click on profile photo
#     - Go to 'My Account'
#     - Scroll down to the API access section and click "Create New API Token"
#     - `kaggle.json` is now downloaded to your computer
#
# 2. Upload the API key and install the Kaggle API client by running the next cell (run it again if it throws an error the first time). Also, `files.upload()` may not work in Firefox. One solution is to expand the Files banner (indicated by the '>' tab on the left side of the page) and use that to upload the key.

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()
# Next, install the Kaggle API client.
# !pip install -q kaggle
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-d7e6e947-5f68-444a-b50b-9feb97db15f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7e6e947-5f68-444a-b50b-9feb97db15f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ls: cannot access 'kaggle.json': No such file or directory
# mv: cannot stat 'kaggle.json': No such file or directory

# %% [markdown]
# 3. Copy the desired dataset locally

# %%
# Example download command for dataset found here: https://www.kaggle.com/akash2907/bird-species-classification
# !kaggle datasets download -d akash2907/bird-species-classification
# Out:
# Downloading bird-species-classification.zip to /content
#  99% 1.36G/1.37G [00:09<00:00, 180MB/s]
# 100% 1.37G/1.37G [00:09<00:00, 154MB/s]

# %% [markdown]
# #### Make the Dataset class
# See the implementation below for reference, and implement a dataset class for the dataset you choose.

# %%
class BirdDataset(Dataset):
    def __init__(self, zip_file='/content/bird-species-classification.zip', size=256, train=True, upload=False):
        super(BirdDataset, self).__init__()
        
        self.train = train
        extract_dir = os.path.splitext(zip_file)[0]
        if not os.path.exists(extract_dir):
            os.makedirs(extract_dir)
            self.extract_zip(zip_file, extract_dir)
            # Resize the images - originally they are high resolution. We could do this
            # in the DataLoader, but it will read the full-resolution files from disk
            # every time before resizing them, making training slow
            self.resize(extract_dir, size=size)

        postfix = 'train' if train else 'test'
            
        if train:
            # The bird-species dataset mistakenly has a train_data folder inside of train_data
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'train_data', 'train_data'), transform=transforms.Compose([transforms.ToTensor()]))
        else:
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'test_data', 'test_data'), transform=transforms.Compose([transforms.ToTensor()]))

    def extract_zip(self, zip_file, extract_dir):
        print("Extracting", zip_file)
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)

    def resize(self, path, size=256):
        """Resizes all images in place"""
        print("Resizing images")
        dirs = os.walk(path)
        for root, dirs, files in os.walk(path):
            for item in files:
                name = os.path.join(root, item)
                if os.path.isfile(name):
                    im = Image.open(name)
                    im = ImageOps.fit(im, (size, size))
                    im.save(name[:-3] + 'bmp', 'BMP')
                    os.remove(name)

    def __getitem__(self, i):
        return self.dataset_folder[i]

    def __len__(self):
        return len(self.dataset_folder)

bird_data = BirdDataset()

# %%
#########################
# Implement your own Dataset - Connor said we could just use BirdDataset
#########################

# %% [markdown]
# ### 1.2 Wrap a pretrained ResNet in an `nn.Module` (30 min)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Make a model class that inherits from `nn.Module`
# - Wrap a pretrained ResNet and swap out the last layer of that network with a layer that maps to the number of classes in your new dataset - done

# %% [markdown]
# #### Make your model class

# %%
class CustomResNet(nn.Module):
    def __init__(self, num_classes, start_frozen=False):
        super(CustomResNet, self).__init__()

        # Part 1.2
        # Load the model - make sure it is pre-trained
        self.model = resnet152(pretrained=True)

        # Part 1.4
        if start_frozen:
            # Turn off all gradients of the resnet
            for param in self.model.parameters():
                param.requires_grad =False
        
        # Part 1.2
        # Look at the code of torchvision.models.resnet152 (or print the ResNet object) to find the name of the attribute to override (the last layer of the ResNet)
        # Override the output linear layer of the neural network to map to the correct number of classes. Note that this new layer has requires_grad = True
        # from the ResNet class definition we see that the final fully-connected layer is stored in model.fc:
        fc_inputs = self.model.fc.in_features
        self.model.fc = nn.Linear(fc_inputs, num_classes)
        
    def unfreeze(self, n_layers):
        # Part 1.4
        # Turn on gradients for the last n_layers
        for layer in list(self.model.modules())[-n_layers:]:
            for param in layer.parameters():
                param.requires_grad = True

    def forward(self, x):
        # Part 1.2
        # Pass x through the resnet
        return self.model(x)

# %%
CustomResNet(2).unfreeze(5)

# %% [markdown]
# ### 1.3 Read through and run this training loop

# %%
def accuracy(y_hat, y_truth):
    """Gets average accuracy of a vector of predictions"""
    
    preds = torch.argmax(y_hat, dim=1)
    acc = torch.mean((preds == y_truth).float())
    return acc

def evaluate(model, objective, val_loader, device):
    """Gets average accuracy and loss for the validation set"""

    val_losses = 0
    val_accs = 0
    batches = 0
    # model.eval() so that batchnorm and dropout work in eval mode
    model.eval()
    # torch.no_grad() to turn off computation graph creation. This allows for temporal
    # and spatial complexity improvements, which allows for larger validation batch 
    # sizes so it’s recommended
    with torch.no_grad():
        for x, y_truth in val_loader:
            
            batches += 1

            x, y_truth = x.to(device), y_truth.to(device)
            y_hat = model(x)
            val_loss = objective(y_hat, y_truth)
            val_acc = accuracy(y_hat, y_truth)

            val_losses += val_loss.item()
            val_accs += val_acc

    model.train()

    return val_losses/batches, val_accs/batches

# %%
def train(start_frozen=False, model_unfreeze=0):
    """Fine-tunes a CNN
    Args:
        start_frozen (bool): whether to start with the network weights frozen.
        model_unfreeze (int): the maximum number of network layers to unfreeze
    """
    epochs = 20
    # Start with a very low learning rate
    lr = .00005
    val_every = 3
    num_classes = 16
    batch_size = 32
    device = torch.device('cuda:0')

    # Data
    # TODO: Use your own dataset
    train_dataset = BirdDataset(upload=True, train=True)
    val_dataset = BirdDataset(upload=True, train=False)
    train_loader = DataLoader(train_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    val_loader = DataLoader(val_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    
    # Model
    model = CustomResNet(num_classes, start_frozen=start_frozen).to(device)
    
    # Objective
    objective = nn.CrossEntropyLoss()
    # Optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-1)

    # Progress bar
    pbar = tqdm(total=len(train_loader) * epochs)

    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    
    cnt = 0
    for epoch in range(epochs):

        # Implement model unfreezing
        if epoch < model_unfreeze:
            model.unfreeze(epoch)
        
        for x, y_truth in train_loader:
        
            x, y_truth = x.to(device), y_truth.to(device)

            optimizer.zero_grad()

            y_hat = model(x)
            train_loss = objective(y_hat, y_truth)
            train_acc = accuracy(y_hat, y_truth)

            train_loss.backward()
            optimizer.step()

            train_accs.append(train_acc)
            train_losses.append(train_loss.item())

            if cnt % val_every == 0:
                val_loss, val_acc = evaluate(model, objective, val_loader, device)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

            pbar.set_description('train loss:{:.4f}, train accuracy:{:.4f}.'.format(train_loss.item(), train_acc))
            pbar.update(1)
            cnt += 1

    pbar.close()
    plt.subplot(121)
    plt.plot(np.arange(len(train_accs)), train_accs, label='Train Accuracy')
    plt.plot(np.arange(len(train_accs), step=val_every), val_accs, label='Val Accuracy')
    plt.legend()
    plt.subplot(122)
    plt.plot(np.arange(len(train_losses)), train_losses, label='Train Loss')
    plt.plot(np.arange(len(train_losses), step=val_every), val_losses, label='Val Loss')
    plt.legend()
    plt.show()

# %%
train(start_frozen=False, model_unfreeze=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
#
# train loss:2.8732, train accuracy:0.0000.:   0%|          | 0/100 [00:07<?, ?it/s]
#
# train loss:2.8732, train accuracy:0.0000.:   1%|          | 1/100 [00:07<12:53,  7.82s/it]
#
# train loss:2.8017, train accuracy:0.0000.:   1%|          | 1/100 [00:09<12:53,  7.82s/it]
#
# train loss:2.8017, train accuracy:0.0000.:   2%|▏         | 2/100 [00:09<07:16,  4.45s/it]
#
# train loss:2.6795, train accuracy:0.1562.:   2%|▏         | 2/100 [00:11<07:16,  4.45s/it]
#
# train loss:2.6795, train accuracy:0.1562.:   3%|▎         | 3/100 [00:11<05:26,  3.37s/it]
#
# train loss:2.6100, train accuracy:0.1875.:   3%|▎         | 3/100 [00:18<05:26,  3.37s/it]
#
# train loss:2.6100, train accuracy:0.1875.:   4%|▍         | 4/100 [00:18<07:31,  4.70s/it]
#
# train loss:2.5478, train accuracy:0.4091.:   4%|▍         | 4/100 [00:20<07:31,  4.70s/it]
#
# train loss:2.5478, train accuracy:0.4091.:   5%|▌         | 5/100 [00:20<05:43,  3.62s/it]
#
# train loss:2.2254, train accuracy:0.6562.:   5%|▌         | 5/100 [00:23<05:43,  3.62s/it]
#
# train loss:2.2254, train accuracy:0.6562.:   6%|▌         | 6/100 [00:23<05:37,  3.59s/it]
#
# train loss:2.1694, train accuracy:0.6562.:   6%|▌         | 6/100 [00:30<05:37,  3.59s/it]
#
# train loss:2.1694, train accuracy:0.6562.:   7%|▋         | 7/100 [00:30<07:10,  4.62s/it]
#
# train loss:2.1444, train accuracy:0.7188.:   7%|▋         | 7/100 [00:32<07:10,  4.62s/it]
#
# train loss:2.1444, train accuracy:0.7188.:   8%|▊         | 8/100 [00:32<05:51,  3.82s/it]
#
# train loss:2.0163, train accuracy:0.7812.:   8%|▊         | 8/100 [00:34<05:51,  3.82s/it]
#
# train loss:2.0163, train accuracy:0.7812.:   9%|▉         | 9/100 [00:34<04:58,  3.28s/it]
#
# train loss:2.0516, train accuracy:0.8636.:   9%|▉         | 9/100 [00:41<04:58,  3.28s/it]
#
# train loss:2.0516, train accuracy:0.8636.:  10%|█         | 10/100 [00:41<06:22,  4.25s/it]
#
# train loss:1.7231, train accuracy:0.9688.:  10%|█         | 10/100 [00:44<06:22,  4.25s/it]
#
# train loss:1.7231, train accuracy:0.9688.:  11%|█         | 11/100 [00:44<05:59,  4.04s/it]
#
# train loss:1.7040, train accuracy:0.9688.:  11%|█         | 11/100 [00:46<05:59,  4.04s/it]
#
# train loss:1.7040, train accuracy:0.9688.:  12%|█▏        | 12/100 [00:46<05:03,  3.45s/it]
#
# train loss:1.6697, train accuracy:1.0000.:  12%|█▏        | 12/100 [00:53<05:03,  3.45s/it]
#
# train loss:1.6697, train accuracy:1.0000.:  13%|█▎        | 13/100 [00:53<06:28,  4.46s/it]
#
# train loss:1.6239, train accuracy:0.9688.:  13%|█▎        | 13/100 [00:55<06:28,  4.46s/it]
#
# train loss:1.6239, train accuracy:0.9688.:  14%|█▍        | 14/100 [00:55<05:22,  3.75s/it]
#
# train loss:1.6707, train accuracy:0.7273.:  14%|█▍        | 14/100 [00:57<05:22,  3.75s/it]
#
# train loss:1.6707, train accuracy:0.7273.:  15%|█▌        | 15/100 [00:57<04:26,  3.13s/it]
#
# train loss:1.4680, train accuracy:0.9062.:  15%|█▌        | 15/100 [01:05<04:26,  3.13s/it]
#
# train loss:1.4680, train accuracy:0.9062.:  16%|█▌        | 16/100 [01:05<06:31,  4.66s/it]
#
# train loss:1.3030, train accuracy:1.0000.:  16%|█▌        | 16/100 [01:07<06:31,  4.66s/it]
#
# train loss:1.3030, train accuracy:1.0000.:  17%|█▋        | 17/100 [01:07<05:23,  3.89s/it]
#
# train loss:1.2691, train accuracy:0.9688.:  17%|█▋        | 17/100 [01:10<05:23,  3.89s/it]
#
# train loss:1.2691, train accuracy:0.9688.:  18%|█▊        | 18/100 [01:10<04:34,  3.35s/it]
#
# train loss:1.2031, train accuracy:0.9688.:  18%|█▊        | 18/100 [01:16<04:34,  3.35s/it]
#
# train loss:1.2031, train accuracy:0.9688.:  19%|█▉        | 19/100 [01:16<05:54,  4.38s/it]
#
# train loss:1.2984, train accuracy:0.9545.:  19%|█▉        | 19/100 [01:18<05:54,  4.38s/it]
#
# train loss:1.2984, train accuracy:0.9545.:  20%|██        | 20/100 [01:18<04:45,  3.57s/it]
#
# train loss:1.0791, train accuracy:1.0000.:  20%|██        | 20/100 [01:22<04:45,  3.57s/it]
#
# train loss:1.0791, train accuracy:1.0000.:  21%|██        | 21/100 [01:22<04:43,  3.59s/it]
#
# train loss:1.0641, train accuracy:0.9688.:  21%|██        | 21/100 [01:28<04:43,  3.59s/it]
#
# train loss:1.0641, train accuracy:0.9688.:  22%|██▏       | 22/100 [01:28<05:55,  4.55s/it]
#
# train loss:1.1088, train accuracy:0.9375.:  22%|██▏       | 22/100 [01:30<05:55,  4.55s/it]
#
# train loss:1.1088, train accuracy:0.9375.:  23%|██▎       | 23/100 [01:31<04:53,  3.82s/it]
#
# train loss:0.8657, train accuracy:1.0000.:  23%|██▎       | 23/100 [01:33<04:53,  3.82s/it]
#
# train loss:0.8657, train accuracy:1.0000.:  24%|██▍       | 24/100 [01:33<04:10,  3.30s/it]
#
# train loss:1.2897, train accuracy:0.8636.:  24%|██▍       | 24/100 [01:39<04:10,  3.30s/it]
#
# train loss:1.2897, train accuracy:0.8636.:  25%|██▌       | 25/100 [01:39<05:17,  4.23s/it]
#
# train loss:0.8379, train accuracy:1.0000.:  25%|██▌       | 25/100 [01:43<05:17,  4.23s/it]
#
# train loss:0.8379, train accuracy:1.0000.:  26%|██▌       | 26/100 [01:43<04:59,  4.04s/it]
#
# train loss:0.8729, train accuracy:1.0000.:  26%|██▌       | 26/100 [01:45<04:59,  4.04s/it]
#
# train loss:0.8729, train accuracy:1.0000.:  27%|██▋       | 27/100 [01:45<04:12,  3.46s/it]
#
# train loss:0.8483, train accuracy:1.0000.:  27%|██▋       | 27/100 [01:51<04:12,  3.46s/it]
#
# train loss:0.8483, train accuracy:1.0000.:  28%|██▊       | 28/100 [01:51<05:20,  4.45s/it]
#
# train loss:0.6963, train accuracy:1.0000.:  28%|██▊       | 28/100 [01:54<05:20,  4.45s/it]
#
# train loss:0.6963, train accuracy:1.0000.:  29%|██▉       | 29/100 [01:54<04:25,  3.74s/it]
#
# train loss:0.8656, train accuracy:1.0000.:  29%|██▉       | 29/100 [01:55<04:25,  3.74s/it]
#
# train loss:0.8656, train accuracy:1.0000.:  30%|███       | 30/100 [01:55<03:39,  3.13s/it]
#
# train loss:0.6478, train accuracy:1.0000.:  30%|███       | 30/100 [02:03<03:39,  3.13s/it]
#
# train loss:0.6478, train accuracy:1.0000.:  31%|███       | 31/100 [02:03<05:19,  4.63s/it]
#
# train loss:0.5054, train accuracy:1.0000.:  31%|███       | 31/100 [02:05<05:19,  4.63s/it]
#
# train loss:0.5054, train accuracy:1.0000.:  32%|███▏      | 32/100 [02:05<04:23,  3.87s/it]
#
# train loss:0.6072, train accuracy:0.9688.:  32%|███▏      | 32/100 [02:08<04:23,  3.87s/it]
#
# train loss:0.6072, train accuracy:0.9688.:  33%|███▎      | 33/100 [02:08<03:43,  3.34s/it]
#
# train loss:0.6564, train accuracy:1.0000.:  33%|███▎      | 33/100 [02:14<03:43,  3.34s/it]
#
# train loss:0.6564, train accuracy:1.0000.:  34%|███▍      | 34/100 [02:14<04:49,  4.38s/it]
#
# train loss:0.6104, train accuracy:1.0000.:  34%|███▍      | 34/100 [02:16<04:49,  4.38s/it]
#
# train loss:0.6104, train accuracy:1.0000.:  35%|███▌      | 35/100 [02:16<03:52,  3.58s/it]
#
# train loss:0.4250, train accuracy:1.0000.:  35%|███▌      | 35/100 [02:19<03:52,  3.58s/it]
#
# train loss:0.4250, train accuracy:1.0000.:  36%|███▌      | 36/100 [02:20<03:45,  3.53s/it]
#
# train loss:0.4596, train accuracy:1.0000.:  36%|███▌      | 36/100 [02:26<03:45,  3.53s/it]
#
# train loss:0.4596, train accuracy:1.0000.:  37%|███▋      | 37/100 [02:26<04:44,  4.51s/it]
#
# train loss:0.4888, train accuracy:1.0000.:  37%|███▋      | 37/100 [02:28<04:44,  4.51s/it]
#
# train loss:0.4888, train accuracy:1.0000.:  38%|███▊      | 38/100 [02:28<03:54,  3.79s/it]
#
# train loss:0.5059, train accuracy:1.0000.:  38%|███▊      | 38/100 [02:30<03:54,  3.79s/it]
#
# train loss:0.5059, train accuracy:1.0000.:  39%|███▉      | 39/100 [02:31<03:19,  3.28s/it]
#
# train loss:0.3928, train accuracy:1.0000.:  39%|███▉      | 39/100 [02:37<03:19,  3.28s/it]
#
# train loss:0.3928, train accuracy:1.0000.:  40%|████      | 40/100 [02:37<04:13,  4.22s/it]
#
# train loss:0.3447, train accuracy:1.0000.:  40%|████      | 40/100 [02:40<04:13,  4.22s/it]
#
# train loss:0.3447, train accuracy:1.0000.:  41%|████      | 41/100 [02:40<03:57,  4.02s/it]
#
# train loss:0.3247, train accuracy:1.0000.:  41%|████      | 41/100 [02:43<03:57,  4.02s/it]
#
# train loss:0.3247, train accuracy:1.0000.:  42%|████▏     | 42/100 [02:43<03:19,  3.45s/it]
#
# train loss:0.3154, train accuracy:1.0000.:  42%|████▏     | 42/100 [02:49<03:19,  3.45s/it]
#
# train loss:0.3154, train accuracy:1.0000.:  43%|████▎     | 43/100 [02:49<04:13,  4.44s/it]
#
# train loss:0.5214, train accuracy:1.0000.:  43%|████▎     | 43/100 [02:51<04:13,  4.44s/it]
#
# train loss:0.5214, train accuracy:1.0000.:  44%|████▍     | 44/100 [02:51<03:29,  3.74s/it]
#
# train loss:0.3680, train accuracy:1.0000.:  44%|████▍     | 44/100 [02:53<03:29,  3.74s/it]
#
# train loss:0.3680, train accuracy:1.0000.:  45%|████▌     | 45/100 [02:53<02:51,  3.13s/it]
#
# train loss:0.2877, train accuracy:1.0000.:  45%|████▌     | 45/100 [03:01<02:51,  3.13s/it]
#
# train loss:0.2877, train accuracy:1.0000.:  46%|████▌     | 46/100 [03:01<04:13,  4.69s/it]
#
# train loss:0.2486, train accuracy:1.0000.:  46%|████▌     | 46/100 [03:04<04:13,  4.69s/it]
#
# train loss:0.2486, train accuracy:1.0000.:  47%|████▋     | 47/100 [03:04<03:27,  3.91s/it]
#
# train loss:0.3302, train accuracy:1.0000.:  47%|████▋     | 47/100 [03:06<03:27,  3.91s/it]
#
# train loss:0.3302, train accuracy:1.0000.:  48%|████▊     | 48/100 [03:06<02:55,  3.37s/it]
#
# train loss:0.3797, train accuracy:1.0000.:  48%|████▊     | 48/100 [03:13<02:55,  3.37s/it]
#
# train loss:0.3797, train accuracy:1.0000.:  49%|████▉     | 49/100 [03:13<03:44,  4.41s/it]
#
# train loss:0.2438, train accuracy:1.0000.:  49%|████▉     | 49/100 [03:14<03:44,  4.41s/it]
#
# train loss:0.2438, train accuracy:1.0000.:  50%|█████     | 50/100 [03:14<02:59,  3.60s/it]
#
# train loss:0.1910, train accuracy:1.0000.:  50%|█████     | 50/100 [03:18<02:59,  3.60s/it]
#
# train loss:0.1910, train accuracy:1.0000.:  51%|█████     | 51/100 [03:18<02:56,  3.60s/it]
#
# train loss:0.2069, train accuracy:1.0000.:  51%|█████     | 51/100 [03:25<02:56,  3.60s/it]
#
# train loss:0.2069, train accuracy:1.0000.:  52%|█████▏    | 52/100 [03:25<03:39,  4.56s/it]
#
# train loss:0.1729, train accuracy:1.0000.:  52%|█████▏    | 52/100 [03:27<03:39,  4.56s/it]
#
# train loss:0.1729, train accuracy:1.0000.:  53%|█████▎    | 53/100 [03:27<02:59,  3.83s/it]
#
# train loss:0.2059, train accuracy:1.0000.:  53%|█████▎    | 53/100 [03:29<02:59,  3.83s/it]
#
# train loss:0.2059, train accuracy:1.0000.:  54%|█████▍    | 54/100 [03:29<02:32,  3.31s/it]
#
# train loss:0.3696, train accuracy:1.0000.:  54%|█████▍    | 54/100 [03:35<02:32,  3.31s/it]
#
# train loss:0.3696, train accuracy:1.0000.:  55%|█████▌    | 55/100 [03:35<03:11,  4.25s/it]
#
# train loss:0.2492, train accuracy:1.0000.:  55%|█████▌    | 55/100 [03:39<03:11,  4.25s/it]
#
# train loss:0.2492, train accuracy:1.0000.:  56%|█████▌    | 56/100 [03:39<02:58,  4.06s/it]
#
# train loss:0.1943, train accuracy:1.0000.:  56%|█████▌    | 56/100 [03:41<02:58,  4.06s/it]
#
# train loss:0.1943, train accuracy:1.0000.:  57%|█████▋    | 57/100 [03:41<02:29,  3.47s/it]
#
# train loss:0.1386, train accuracy:1.0000.:  57%|█████▋    | 57/100 [03:48<02:29,  3.47s/it]
#
# train loss:0.1386, train accuracy:1.0000.:  58%|█████▊    | 58/100 [03:48<03:07,  4.47s/it]
#
# train loss:0.1558, train accuracy:1.0000.:  58%|█████▊    | 58/100 [03:50<03:07,  4.47s/it]
#
# train loss:0.1558, train accuracy:1.0000.:  59%|█████▉    | 59/100 [03:50<02:34,  3.76s/it]
#
# train loss:0.1911, train accuracy:1.0000.:  59%|█████▉    | 59/100 [03:52<02:34,  3.76s/it]
#
# train loss:0.1911, train accuracy:1.0000.:  60%|██████    | 60/100 [03:52<02:05,  3.14s/it]
#
# train loss:0.2725, train accuracy:1.0000.:  60%|██████    | 60/100 [04:00<02:05,  3.14s/it]
#
# train loss:0.2725, train accuracy:1.0000.:  61%|██████    | 61/100 [04:00<03:02,  4.68s/it]
#
# train loss:0.1367, train accuracy:1.0000.:  61%|██████    | 61/100 [04:02<03:02,  4.68s/it]
#
# train loss:0.1367, train accuracy:1.0000.:  62%|██████▏   | 62/100 [04:02<02:28,  3.90s/it]
#
# train loss:0.1390, train accuracy:1.0000.:  62%|██████▏   | 62/100 [04:04<02:28,  3.90s/it]
#
# train loss:0.1390, train accuracy:1.0000.:  63%|██████▎   | 63/100 [04:04<02:04,  3.36s/it]
#
# train loss:0.1334, train accuracy:1.0000.:  63%|██████▎   | 63/100 [04:11<02:04,  3.36s/it]
#
# train loss:0.1334, train accuracy:1.0000.:  64%|██████▍   | 64/100 [04:11<02:38,  4.40s/it]
#
# train loss:0.1855, train accuracy:1.0000.:  64%|██████▍   | 64/100 [04:13<02:38,  4.40s/it]
#
# train loss:0.1855, train accuracy:1.0000.:  65%|██████▌   | 65/100 [04:13<02:05,  3.59s/it]
#
# train loss:0.1208, train accuracy:1.0000.:  65%|██████▌   | 65/100 [04:16<02:05,  3.59s/it]
#
# train loss:0.1208, train accuracy:1.0000.:  66%|██████▌   | 66/100 [04:16<02:01,  3.59s/it]
#
# train loss:0.1168, train accuracy:1.0000.:  66%|██████▌   | 66/100 [04:23<02:01,  3.59s/it]
#
# train loss:0.1168, train accuracy:1.0000.:  67%|██████▋   | 67/100 [04:23<02:29,  4.55s/it]
#
# train loss:0.1301, train accuracy:1.0000.:  67%|██████▋   | 67/100 [04:25<02:29,  4.55s/it]
#
# train loss:0.1301, train accuracy:1.0000.:  68%|██████▊   | 68/100 [04:25<02:02,  3.82s/it]
#
# train loss:0.1298, train accuracy:1.0000.:  68%|██████▊   | 68/100 [04:27<02:02,  3.82s/it]
#
# train loss:0.1298, train accuracy:1.0000.:  69%|██████▉   | 69/100 [04:27<01:42,  3.31s/it]
#
# train loss:0.1370, train accuracy:1.0000.:  69%|██████▉   | 69/100 [04:34<01:42,  3.31s/it]
#
# train loss:0.1370, train accuracy:1.0000.:  70%|███████   | 70/100 [04:34<02:07,  4.24s/it]
#
# train loss:0.1404, train accuracy:1.0000.:  70%|███████   | 70/100 [04:37<02:07,  4.24s/it]
#
# train loss:0.1404, train accuracy:1.0000.:  71%|███████   | 71/100 [04:37<01:57,  4.06s/it]
#
# train loss:0.0869, train accuracy:1.0000.:  71%|███████   | 71/100 [04:39<01:57,  4.06s/it]
#
# train loss:0.0869, train accuracy:1.0000.:  72%|███████▏  | 72/100 [04:39<01:37,  3.47s/it]
#
# train loss:0.1098, train accuracy:1.0000.:  72%|███████▏  | 72/100 [04:46<01:37,  3.47s/it]
#
# train loss:0.1098, train accuracy:1.0000.:  73%|███████▎  | 73/100 [04:46<01:59,  4.43s/it]
#
# train loss:0.1302, train accuracy:1.0000.:  73%|███████▎  | 73/100 [04:48<01:59,  4.43s/it]
#
# train loss:0.1302, train accuracy:1.0000.:  74%|███████▍  | 74/100 [04:48<01:36,  3.73s/it]
#
# train loss:0.1774, train accuracy:1.0000.:  74%|███████▍  | 74/100 [04:50<01:36,  3.73s/it]
#
# train loss:0.1774, train accuracy:1.0000.:  75%|███████▌  | 75/100 [04:50<01:18,  3.12s/it]
#
# train loss:0.1006, train accuracy:1.0000.:  75%|███████▌  | 75/100 [04:58<01:18,  3.12s/it]
#
# train loss:0.1006, train accuracy:1.0000.:  76%|███████▌  | 76/100 [04:58<01:51,  4.66s/it]
#
# train loss:0.1209, train accuracy:1.0000.:  76%|███████▌  | 76/100 [05:00<01:51,  4.66s/it]
#
# train loss:0.1209, train accuracy:1.0000.:  77%|███████▋  | 77/100 [05:00<01:29,  3.89s/it]
#
# train loss:0.0990, train accuracy:1.0000.:  77%|███████▋  | 77/100 [05:02<01:29,  3.89s/it]
#
# train loss:0.0990, train accuracy:1.0000.:  78%|███████▊  | 78/100 [05:02<01:13,  3.35s/it]
#
# train loss:0.1523, train accuracy:1.0000.:  78%|███████▊  | 78/100 [05:09<01:13,  3.35s/it]
#
# train loss:0.1523, train accuracy:1.0000.:  79%|███████▉  | 79/100 [05:09<01:32,  4.40s/it]
#
# train loss:0.2543, train accuracy:1.0000.:  79%|███████▉  | 79/100 [05:11<01:32,  4.40s/it]
#
# train loss:0.2543, train accuracy:1.0000.:  80%|████████  | 80/100 [05:11<01:11,  3.59s/it]
#
# train loss:0.0862, train accuracy:1.0000.:  80%|████████  | 80/100 [05:14<01:11,  3.59s/it]
#
# train loss:0.0862, train accuracy:1.0000.:  81%|████████  | 81/100 [05:14<01:08,  3.59s/it]
#
# train loss:0.1262, train accuracy:1.0000.:  81%|████████  | 81/100 [05:21<01:08,  3.59s/it]
#
# train loss:0.1262, train accuracy:1.0000.:  82%|████████▏ | 82/100 [05:21<01:21,  4.54s/it]
#
# train loss:0.1496, train accuracy:1.0000.:  82%|████████▏ | 82/100 [05:23<01:21,  4.54s/it]
#
# train loss:0.1496, train accuracy:1.0000.:  83%|████████▎ | 83/100 [05:23<01:04,  3.81s/it]
#
# train loss:0.1057, train accuracy:1.0000.:  83%|████████▎ | 83/100 [05:25<01:04,  3.81s/it]
#
# train loss:0.1057, train accuracy:1.0000.:  84%|████████▍ | 84/100 [05:25<00:52,  3.30s/it]
#
# train loss:0.1681, train accuracy:1.0000.:  84%|████████▍ | 84/100 [05:32<00:52,  3.30s/it]
#
# train loss:0.1681, train accuracy:1.0000.:  85%|████████▌ | 85/100 [05:32<01:03,  4.22s/it]
#
# train loss:0.1163, train accuracy:1.0000.:  85%|████████▌ | 85/100 [05:35<01:03,  4.22s/it]
#
# train loss:0.1163, train accuracy:1.0000.:  86%|████████▌ | 86/100 [05:35<00:56,  4.02s/it]
#
# train loss:0.1065, train accuracy:1.0000.:  86%|████████▌ | 86/100 [05:37<00:56,  4.02s/it]
#
# train loss:0.1065, train accuracy:1.0000.:  87%|████████▋ | 87/100 [05:37<00:44,  3.45s/it]
#
# train loss:0.0743, train accuracy:1.0000.:  87%|████████▋ | 87/100 [05:44<00:44,  3.45s/it]
#
# train loss:0.0743, train accuracy:1.0000.:  88%|████████▊ | 88/100 [05:44<00:53,  4.45s/it]
#
# train loss:0.0917, train accuracy:1.0000.:  88%|████████▊ | 88/100 [05:46<00:53,  4.45s/it]
#
# train loss:0.0917, train accuracy:1.0000.:  89%|████████▉ | 89/100 [05:46<00:41,  3.75s/it]
#
# train loss:0.1415, train accuracy:1.0000.:  89%|████████▉ | 89/100 [05:48<00:41,  3.75s/it]
#
# train loss:0.1415, train accuracy:1.0000.:  90%|█████████ | 90/100 [05:48<00:31,  3.14s/it]
#
# train loss:0.0773, train accuracy:1.0000.:  90%|█████████ | 90/100 [05:56<00:31,  3.14s/it]
#
# train loss:0.0773, train accuracy:1.0000.:  91%|█████████ | 91/100 [05:56<00:42,  4.69s/it]
#
# train loss:0.0764, train accuracy:1.0000.:  91%|█████████ | 91/100 [05:58<00:42,  4.69s/it]
#
# train loss:0.0764, train accuracy:1.0000.:  92%|█████████▏| 92/100 [05:58<00:31,  3.92s/it]
#
# train loss:0.1127, train accuracy:1.0000.:  92%|█████████▏| 92/100 [06:01<00:31,  3.92s/it]
#
# train loss:0.1127, train accuracy:1.0000.:  93%|█████████▎| 93/100 [06:01<00:23,  3.37s/it]
#
# train loss:0.0786, train accuracy:1.0000.:  93%|█████████▎| 93/100 [06:07<00:23,  3.37s/it]
#
# train loss:0.0786, train accuracy:1.0000.:  94%|█████████▍| 94/100 [06:07<00:26,  4.38s/it]
#
# train loss:0.1410, train accuracy:0.9545.:  94%|█████████▍| 94/100 [06:09<00:26,  4.38s/it]
#
# train loss:0.1410, train accuracy:0.9545.:  95%|█████████▌| 95/100 [06:09<00:17,  3.58s/it]
#
# train loss:0.1397, train accuracy:1.0000.:  95%|█████████▌| 95/100 [06:13<00:17,  3.58s/it]
#
# train loss:0.1397, train accuracy:1.0000.:  96%|█████████▌| 96/100 [06:13<00:14,  3.58s/it]
#
# train loss:0.1042, train accuracy:1.0000.:  96%|█████████▌| 96/100 [06:19<00:14,  3.58s/it]
#
# train loss:0.1042, train accuracy:1.0000.:  97%|█████████▋| 97/100 [06:19<00:13,  4.53s/it]
#
# train loss:0.1110, train accuracy:1.0000.:  97%|█████████▋| 97/100 [06:21<00:13,  4.53s/it]
#
# train loss:0.1110, train accuracy:1.0000.:  98%|█████████▊| 98/100 [06:21<00:07,  3.80s/it]
#
# train loss:0.0979, train accuracy:1.0000.:  98%|█████████▊| 98/100 [06:24<00:07,  3.80s/it]
#
# train loss:0.0979, train accuracy:1.0000.:  99%|█████████▉| 99/100 [06:24<00:03,  3.29s/it]
#
# train loss:0.1184, train accuracy:1.0000.:  99%|█████████▉| 99/100 [06:30<00:03,  3.29s/it]
#
# train loss:0.1184, train accuracy:1.0000.: 100%|██████████| 100/100 [06:30<00:00,  3.91s/it]

# %% [markdown]
# ### 1.4 Implement Unfreezing (1 hr)

# %% [markdown]
# #### Description

# %% [markdown]
# Unfreezing is a technique that can be helpful when fine tuning a CNN for a more difficult task with a large amount of data.
#
# The idea is that if we allow the network to tweak the earliest layers immediately, before the last FCL has been trained at all, the earliest layers will forget all of the useful features that they learned in order  to provide features that are helpful for the (untrained) FCL.
#
# So, rather than training all of the model weights at once, we learn the last fully connected layer, then train that layer together with the second-to-last layer, gradually adding layers until we reach the first layer.

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Modify your model's parameters by setting the `requires_grad` attributes to `False`. (but keep `requires_grad = True` for the last layer). - done
# - Add a member function to you model class that allows the user to unfreeze weights in the training loop. See [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c) for reference. - done
# - Modify your training loop to add logic that calls the `unfreeze` function of the model class: unfreeze one layer (a convolutional layer or linear layer, not the sequential or bottleneck layers) every epoch. - done
# - Call your train function to fine-tune the ResNet on your dataset.

# %% [markdown]
# #### Call your train function

# %%
############################
# train with unfreezing here (should be a single call to your train function)
############################
train(start_frozen=True, model_unfreeze=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# train loss:0.1420, train accuracy:1.0000.: 100%|██████████| 100/100 [05:54<00:00,  3.54s/it]

# %% [markdown]
# You may not see any improvement for your classification task, but unfreezing can help convergence for more difficult image classification tasks.

# %% [markdown]
# ## 2 Fine-tune a language model - (15 min)

# %% [markdown]
# In this section you will use the gpt-2-simple package [here](https://github.com/minimaxir/gpt-2-simple) to fine-tune the GPT-2 language model on a domain of your choice.

# %% [markdown]
# ### 2.1 Generate text from an the pretrained GPT-2 model

# %% [markdown]
# #### Run this code to generate text from a pretrained model

# %%
# !pip install gpt-2-simple

# the transformers package is built on top of Tensorflow, and the default TF version 
# for Colab will soon switch to 2.x. We remedy this with the following magic method
# %tensorflow_version 1.x 

import gpt_2_simple as gpt2
import os
import tensorflow as tf
# Out:
# Requirement already satisfied: gpt-2-simple in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: toposort in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (1.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (4.62.3)
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gpt-2-simple) (1.19.5)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.12.1)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.17.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.15.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (5.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.1.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.12.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.12)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.37.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.41.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.1.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.1->gpt-2-simple) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.1->gpt-2-simple) (3.6.0)
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# This line is necessary to be able to run a new tf session
tf.reset_default_graph()
# The medium-sized model. IF you run out of memory, try "124M" instead
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/

sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, model_name=model_name)
gpt2.generate(sess, model_name=model_name)
# Out:
# Loading pretrained model models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# The story of the far-right UK Independence Party is not about free speech nor about freedom of speech, but about the rise of a powerful and frightening movement, one that is, at its core, about nationalism and the promotion of the right to self-determination.
#
# The plan for a far-right British National party, which has been incensed by Nigel Farage's xenophobic remarks about Muslims, is not about freedom of speech, but about the rise of a powerful and frightening movement, one that is, at its core, about nationalism and the promotion of the right to self-determination.
#
# The GOP has been at the centre of a debate about multiculturalism ever since the 1960s. The party, which has seen its membership grow from just 30 members in 2005 to every about 30 in 2014, is seen as a racist party.
#
# But it is also a cause célèbre for the political right. The right-wing National Front has been campaigning for years on the idea that the British people should choose between a multicultural Britain and a British Empire.
#
# It is a movement with grown-up, hardline elements, but it is also a movement that is battling the crown.
#
# The UK Independence Party (UKIP) is a far-right UK Independence Party (UKIP) is a far-right UK Independence Party (UKIP)
#
# The right-wing movement has long been associated with the so-called Islamic State. It has long been associated with the so-called Islamic State (IS).
#
# Its views on immigration and the role of the UK in the Middle East are wildly different from the views of the UK Independence Party.
#
# To the extent that the UK Independence Party is a far-right party, it has a very strong focus on the policy of increasing security for immigration.
#
# It is not a party that is playing for the British people. It is a movement that is fighting the crown.
#
# Far-right British National Party (FBN) leader Nigel Farage held a press conference on the eve of the UK Independence Party's 2016 general election campaign to announce the party was taking part in a new section of the campaign called "Migration UK".
#
# Farage said UKIP's new section was aimed at "removing the UK from an empire that is broken up by multiculturalism."
#
# He said the party's focus on immigration had been part of its aim since 2001, when it was formed.
#
# Farage said: "This new section of UKIP represents the best interests of the migrants and we are proud to be part of this campaign.
#
# "We want to create a new world order that protects the rights and interests of all immigrants and their families in the UK.
#
# "We believe that Britain's borders must be closed and the powers, of course, must be increased to ensure stability and security for all migrants.
#
# "We want to abolish the European Union, which is designed to protect the interests of all immigrants."
#
# It is not just the UK national party that is using Farage's speech to recruit new supporters. It is the far-right British National Party (FBN) that is following in the footsteps of the far-right British National Party (FPC) in the UK.
#
# The party, which has been at the centre of a debate about multiculturalism ever since the 1960s, is seen as a racist party
#
# The FBN has written to MEPs seeking help to form a new national party, often known as "the national party or the national party".
#
# The FBN has written to MEPs seeking help to form a new national party, often known as "the national party or the national party".
#
# The FBN has been at the centre of a debate about multiculturalism ever since the 1960s, when it was founded
#
# Most of the far-right British National Party (FBN) and their supporters are immigrants
#
# The FBN has said there are serious doubts over the quality of the overall policy of immigration and security.
#
# Farage said: "We have a very strong policy of increasing security for immigration. It's actually a range of different things that are going on, some of which are very serious, some of which are not.
#
# "But the main issue is immigration, and as I have said before, we have a very strong national policy about immigration.
#
# "It is now under review.
#
# "We have to look at how we can address the need for the number of Muslims in the UK. If we don't have the means to deal with that then we have a very strong, very effective policy aimed at reducing immigration.
#
# "So it is a big question whether we can succeed at this or not. There are certainly some people who feel that we have to reform immigration.
#
# "But there are some people who do not like the idea that we need to build walls around the European Union and that we have to put in place a

# %% [markdown]
# ### 2.2 Download a text dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Use the provided functions to download your own text dataset
# - [Project Gutenberg](https://www.gutenberg.org/) is a nice starting point for raw text corpora

# %% [markdown]
# #### Download Dataset

# %%
import zipfile
import os
from torchvision import datasets

def extract_zip(zip_path, remove_finished=True):
    print('Extracting {}'.format(zip_path))
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(zip_path.replace('.zip', ''))
    if remove_finished:
        os.remove(zip_path)

def download_dataset(url, root='../data'):
    if not os.path.exists(os.path.join(root, 'text')):
        os.makedirs(os.path.join(root))
        datasets.utils.download_url(url, root, 'text.zip', None)
        extract_zip(os.path.join(root, 'text.zip'))
    return os.path.join(root, 'text')

##########################################
# Set the url for your dataset here,
# move the dataset to the desired location
##########################################
# url = 'https://www.gutenberg.org/files/30/30.zip'
# download_dataset(url)
# !mv /data/text/30.txt /data/text/bible.txt
# !ls ../data/text

url = 'http://corpus.canterbury.ac.nz/resources/cantrbry.zip'
download_dataset(url)
# Out:
# '../data/text'

# %% [markdown]
# ### 2.3 Fine-tune GPT-2 on your own dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Swap out the dataset parameter with the path to your dataset

# %% [markdown]
# #### Train on your dataset

# %%
# This line is necessary to be able to run a new tf session if one has already been run
tf.reset_default_graph()
# Start a session
sess = gpt2.start_tf_sess()
# Fine tune `model_name` on `data`
###################################
# Swap out the `dataset` parameter with the path to your text dataset
###################################
gpt2.finetune(sess,
              dataset='../data/text/shakespeare.txt',
              model_name=model_name,
              restore_from='latest',
              steps=100)   # steps is max number of training steps

gpt2.generate(sess, run_name='run1')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run1/model-119
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-119
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  2.86it/s]
# dataset has 39689 tokens
# Training...
# [120 | 12.41] loss=0.81 avg=0.81
# [121 | 16.80] loss=1.72 avg=1.27
# [122 | 21.17] loss=1.24 avg=1.26
# [123 | 25.57] loss=1.37 avg=1.29
# [124 | 29.96] loss=1.20 avg=1.27
# [125 | 34.34] loss=1.15 avg=1.25
# [126 | 38.73] loss=0.99 avg=1.21
# [127 | 43.13] loss=1.19 avg=1.21
# [128 | 47.54] loss=1.03 avg=1.19
# [129 | 51.95] loss=1.05 avg=1.17
# [130 | 56.35] loss=0.89 avg=1.14
# [131 | 60.77] loss=1.06 avg=1.14
# [132 | 65.17] loss=0.78 avg=1.11
# [133 | 69.59] loss=0.82 avg=1.09
# [134 | 74.01] loss=1.25 avg=1.10
# [135 | 78.46] loss=1.30 avg=1.11
# [136 | 82.88] loss=1.14 avg=1.11
# [137 | 87.31] loss=0.74 avg=1.09
# [138 | 91.73] loss=0.70 avg=1.07
# [139 | 96.15] loss=0.67 avg=1.05
# [140 | 100.58] loss=0.79 avg=1.03
# [141 | 105.01] loss=0.58 avg=1.01
# [142 | 109.44] loss=0.61 avg=0.99
# [143 | 113.85] loss=0.52 avg=0.97
# [144 | 118.30] loss=0.94 avg=0.97
# [145 | 122.73] loss=0.91 avg=0.97
# [146 | 127.15] loss=0.55 avg=0.95
# [147 | 131.58] loss=0.68 avg=0.94
# [148 | 136.01] loss=0.54 avg=0.92
# [149 | 140.44] loss=0.55 avg=0.91
# [150 | 144.86] loss=0.57 avg=0.89
# [151 | 149.29] loss=0.69 avg=0.89
# [152 | 153.72] loss=0.64 avg=0.88
# [153 | 158.16] loss=0.74 avg=0.87
# [154 | 162.60] loss=0.47 avg=0.86
# [155 | 167.02] loss=0.51 avg=0.85
# [156 | 171.44] loss=0.73 avg=0.84
# [157 | 175.88] loss=0.48 avg=0.83
# [158 | 180.31] loss=0.45 avg=0.82
# [159 | 184.75] loss=0.34 avg=0.81
# [160 | 189.18] loss=0.51 avg=0.80
# [161 | 193.62] loss=0.45 avg=0.79
# [162 | 198.05] loss=0.49 avg=0.78
# [163 | 202.48] loss=0.37 avg=0.77
# [164 | 206.90] loss=0.40 avg=0.76
# [165 | 211.33] loss=0.59 avg=0.75
# [166 | 215.77] loss=0.65 avg=0.75
# [167 | 220.19] loss=0.37 avg=0.74
# [168 | 224.61] loss=0.33 avg=0.73
# [169 | 229.04] loss=0.35 avg=0.72
# [170 | 233.47] loss=0.29 avg=0.71
# [171 | 237.89] loss=0.33 avg=0.70
# [172 | 242.32] loss=0.46 avg=0.69
# [173 | 246.76] loss=0.32 avg=0.69
# [174 | 251.19] loss=0.32 avg=0.68
# [175 | 255.60] loss=0.33 avg=0.67
# [176 | 260.02] loss=0.23 avg=0.66
# [177 | 264.48] loss=0.34 avg=0.65
# [178 | 268.92] loss=0.21 avg=0.64
# [179 | 273.34] loss=0.23 avg=0.63
# [180 | 277.78] loss=0.27 avg=0.62
# [181 | 282.21] loss=0.23 avg=0.62
# [182 | 286.64] loss=0.24 avg=0.61
# [183 | 291.07] loss=0.26 avg=0.60
# [184 | 295.50] loss=0.27 avg=0.59
# [185 | 299.93] loss=0.22 avg=0.59
# [186 | 304.37] loss=0.23 avg=0.58
# [187 | 308.80] loss=0.26 avg=0.57
# [188 | 313.25] loss=0.24 avg=0.57
# [189 | 317.69] loss=0.18 avg=0.56
# [190 | 322.13] loss=0.18 avg=0.55
# [191 | 326.57] loss=0.58 avg=0.55
# [192 | 331.00] loss=0.26 avg=0.55
# [193 | 335.42] loss=0.30 avg=0.54
# [194 | 339.84] loss=0.19 avg=0.53
# [195 | 344.26] loss=0.17 avg=0.53
# [196 | 348.70] loss=0.16 avg=0.52
# [197 | 353.12] loss=0.20 avg=0.52
# [198 | 357.57] loss=0.20 avg=0.51
# [199 | 362.00] loss=0.16 avg=0.50
# [200 | 366.42] loss=0.16 avg=0.50
# ======== SAMPLE 1 ========
# ALYSTAL for her husband.
#
# CHARLES	I pray you, tell me where you came from, and I will
# 	tell you wherein you are from.
#
# ORLANDO	Pray you, tell me wherein you are.
#
# ROSALIND	Pray you, are not better met, are we?
#
# CELIA	Say, is thy father in the forest,
# 	That is the only daughter of the sky,
# 	That stays where there are no her
# 	maids, or that goes no further
# 	 than to seek a cave in the ground,
# 	Where she meet shall bellow chide each other and
# 	swoon, and all the world will weep.
#
# ROSALIND	O valiant maiden! brave and pretty all,
# 	Keeps her head but wits about,
# 	High heels on, and a comfortable life in
# 	The world.
#
# CELIA	Or we shall all be like her.
#
# ROSALIND	What do you mean, valiant and pretty?
#
# CELIA	I would you, God be wi' you, look to me!
#
# ROSALIND	Do you think so?
#
# CELIA	Yes; do you think so? Moving on,
# 	Hereafter we visit you in a while.
#
# ORLANDO	How now, Orlando! whither wander you?
#
# CELIA	Go with me to your father's cote and I will
# 	teach thee all sorts of strivings; but first, I would you
# 	thou tell me, who is he that is striv'd against you.
#
# QUINTIN	I am he that is so.
#
# CELIA	Do you speak the manner in which he speaks?
#
# ROSALIND	He hath strange words in his mouth; for he talks in
# 	unabridged; as the boorish will, with his hard
# 	hard measures.
#
# CELIA	Now would I be his oyster man, learning
# 	what he is covetous of, and by him and
# 	else that! Soft! welcome, Jaques!
#
# 	[Enter OLIVER]
#
# OLIVER	Dead Oliver!
#
# ROSALIND	Dear Jaques, I bring you this:
# 	a tale of torpor, fresh from you
# 	and told with much sadness to suit
# 	the disabled man's colour.
#
# OLIVER	What, the poor you, are I to fault?
#
# ROSALIND	You sound even like a fool.
#
# OLIVER	I hope not; but, as I guess, you
# 	cleanly did steal from a poor and motley
# 	wounded state, thrown in a cistern, and
# 	capricorn'd and mutilated like a beggar.
#
# ROSALIND	Why, that thou couldst not read?
#
# OLIVER	Forsooth Lucifer hath a faithful knave in him.
#
# ROSALIND	He recovers his fortunes in this a most humorous
# 	differential.
#
# OLIVER	If thou study'st like so, and not so gauche
# 	like the enchantress of Rosalind
# 	Thou shalt love and marry me, and bestow me,
# 	God willing, upon a woman's head.
#
# ROSALIND	O most wicked and bloody Moses!
#
# OLIVER	Why, who cries out on song when a man
# 	cuts off his own limb?
#
# ROSALIND	Beauty doth make a man fairer than axe.
#
# 	[ROSALIND swoons]
#
# 	Amen.
#
#
# 	rawdownloadcloneembedreportprint text
#
#
# 	STONE	[To OLIVER]
#
# 	I would not have you stay'd at Orlando,
# 	Where I have hated you, hated my enemies, and
# 	Went to church with you. But home, Audrey!
# 	I pray you, stay where you are. I must
# 	dispatch my attendants to your place. The duke
# 	hates me not so much at home as at home I
# 	knows it. Are you Orlando?
#
# CELIA	Yes, sir; yea, I count him near.
#
# OLIVER	You are, sir.
#
# ROSALIND	Then am I; I love Orlando even more than he
# 	knows me.
#
# CELIA	And yet I am not. He calls me heartily.
# 	Am I not the only daughter of Sir
# 	Rowland Orlando?
#
# OLIVER	No, sir; I am the wife of Sir Rowland.
#
# ROSALIND	Your suit is as good as made for you: Orlando
# 	fancies you a
#
# [201 | 389.09] loss=0.16 avg=0.49
# [202 | 393.52] loss=0.15 avg=0.48
# [203 | 397.93] loss=0.16 avg=0.48
# [204 | 402.36] loss=0.18 avg=0.47
# [205 | 406.80] loss=0.14 avg=0.47
# [206 | 411.24] loss=0.16 avg=0.46
# [207 | 415.66] loss=0.15 avg=0.46
# [208 | 420.09] loss=0.14 avg=0.45
# [209 | 424.50] loss=0.10 avg=0.45
# [210 | 428.92] loss=0.11 avg=0.44
# [211 | 433.34] loss=0.15 avg=0.44
# [212 | 437.76] loss=0.31 avg=0.43
# [213 | 442.20] loss=0.12 avg=0.43
# [214 | 446.62] loss=0.15 avg=0.42
# [215 | 451.06] loss=0.17 avg=0.42
# [216 | 455.49] loss=0.13 avg=0.42
# [217 | 459.92] loss=0.10 avg=0.41
# [218 | 464.34] loss=0.22 avg=0.41
# [219 | 468.76] loss=0.12 avg=0.40
# Saving checkpoint/run1/model-219
# What shall we make of this?
#
# ORLANDO	For our life and never to speak of it;
# 	We'll have a priest in the war, if we be willing
# 	Butd-men and villains to live.
#
# ROSALIND	Then have no more of us of our own making;
# 	Keep your promises, and then there will be no
# 	matter: shun this, keep that, for I know not how.
#
# 	[Exeunt]
#
#
#
#
# 	AS YOU LIKE IT
#
#
# ACT III
#
#
#
# SCENE III	The forest.
#
#
# 	[Enter ORLANDO, with a paper]
#
# ROSALIND	And so we shall see to it: between the blue brow and
# 	the rough beard of a man, Orlando looks after his old
# 	respecter.
# 	[Enter SILVIUS]
#
# SILVIUS	I pray you, something more please:
# 	Let's make this matter in our favour.
#
# ORLANDO	I pray you, the matter is; the more you
# 	cried it, the merrier.
#
# ROSALIND	I pray you, do as you are saying.
#
# SILVIUS	I pray you, do as you are saying.
#
# ORLANDO	I pray you, do as you are saying.
#
# ROSALIND	I do as I say. As the wise do, the guilty is.
#
# SILVIUS	I thank you, for your grace and good will to
# 	Know- yourrer Orlando.
#
# ORLANDO	Know you, stranger to this forest?
#
# ROSALIND	I am, sir: and you, sir; for I came to acquaint you
# 	withal, that you might know how to make a man of
# 	nothing, and how I came to acquaint you
# 	with good reason. The first time I saw you was when
# 	you were still in your natural youth, and I think you said the
# 	word to invite my help in making you something.
#
# ORLANDO	I thank you, for your grace and good will to know.
#
# ROSALIND	I do so, sir. I would have you know I was not.
#
# ORLANDO	I pray you, tell me the manner in which you made this man,
# 	made of prime value: and I will lead you
# 	to some man's house, and let me know the value
# 	of that lord's sword.
#
# ROSALIND	I will lead you, sir. Thou art in good earnest, my lord.
#
# ORLANDO	I pray you, tell me the thing: it is a ragged fellow;
# 	but what's the matter? Who's the?
#
# ROSALIND	O sir Rowland, the duke's brother.
#
# ORLANDO	I in good earnest, my lord.
#
# ROSALIND	O, it is, my lord.
#
# ORLANDO	It is not the thing.
#
# ROSALIND	It is not the man.
#
# ORLANDO	Why then, whither, whither, whither?
#
# ROSALIND	O, to thee, to theh, and so on.
#
# 	Thus I will follow the ragged fellow.
#
# 	No more of it; no more this way or the
# 	other.
#
# ORLANDO	I pray you, tell me the matter: and I will, sir;
# 	as soon as I can remember this place.
#
# ROSALIND	There is none behind you; no one else is.
#
# ORLANDO	What, you say, if I told you who was in the house?
#
# ROSALIND	No, by my faith, I say: 'the man.' If you will know his name,
# 	you have better know your brother;'--'Tis he, isn't he?
#
# ORLANDO	How remember his features?
#
# ROSALIND	They were as blank as the world is blank:
# 	blanket of colour, like a blank page;
# 	blanket of small size, like the note of a
# 	lesser man.
#
# ORLANDO	How remember his features?
#
# ROSALIND	They were as black as the face of a
# 	lesser man; and, in blank space,
# 	would suddenly change it to colour.
#
# ORLANDO	How remember his features?
#
# ROSALIND	He was tall and lean and slender and
# 	wicked colour, and a scarlet letter from his
# 	adieu, with a Page contents, across
# 	all hands, muting it with the most bloody Notes,
